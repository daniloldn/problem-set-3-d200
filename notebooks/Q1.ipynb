# %% [markdown]
# ## Question 1: Multi-Armed Bandits for Ad Channel Selection

# %%
from pathlib import Path
import sys

project_root = Path.cwd().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
from src.run_bandit import simulate, simulate_2
from src.policy import run_random, e_greedy, ucb1, tsample

# %% [markdown]
# ### Q1A

# %%
simulate(run_random)

# %% [markdown]
# ### Q1b

# %%
simulate_2({"random":run_random, "e-greedy":e_greedy, "ucb":ucb1, "tsample":tsample})
